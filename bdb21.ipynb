# %% [markdown]
# <a href="https://colab.research.google.com/github/lelarson/Fantasy-Football-Optimization/blob/master/bdb21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# imports

# %%
# !pip install fastai --upgrade
from fastai.vision.all import *
# Out:
# Requirement already up-to-date: fastai in /usr/local/lib/python3.6/dist-packages (2.1.10)
# ...

# %%
images = get_image_files('/Users/logan.larson/Source/personal/fb/bd/dataset1')

# %%
import fastai
fastai.__version__
# Out:
# '2.0.0'

# %%
import fastcore
fastcore.__version__
# Out:
# '1.3.13'
